# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
auto_df = pd.read_csv('auto_mpg_dataset.csv')
print (auto_df.shape)
# Out:
# (398, 9)

# %%
print (auto_df.columns)
# Out:
# Index(['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration',
#        'model_year', 'origin', 'car_name', 'mpg'],
#       dtype='object')

# %%
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cylinders     398 non-null    int64
#  1   displacement  398 non-null    float64
#  2   horsepower    398 non-null    float64
#  3   weight        398 non-null    float64
#  4   acceleration  398 non-null    float64
#  5   model_year    398 non-null    int64
#  6   origin        398 non-null    int64
#  7   car_name      398 non-null    object
#  8   mpg           398 non-null    float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB

# %%
auto_df.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0          8         307.0       130.0  3504.0          12.0          70
# 1          8         350.0       165.0  3693.0          11.5          70
# 2          8         318.0       150.0  3436.0          11.0          70
# 3          8         304.0       150.0  3433.0          12.0          70
# 4          8         302.0       140.0  3449.0          10.5          70
#
#    origin                   car_name   mpg
# 0       1  chevrolet chevelle malibu  18.0
# 1       1          buick skylark 320  15.0
# 2       1         plymouth satellite  18.0
# 3       1              amc rebel sst  16.0
# 4       1                ford torino  17.0

# %%
auto_df['acceleration'].mean()
# Out:
# 15.568090452261291

# %%
auto_df["cylinders"].value_counts().plot.pie(autopct='%1.0f%%')
plt.show()

# %%
sns.heatmap(auto_df.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x= 'horsepower',y='weight',data=auto_df,estimator=np.std)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='weight'>

# %%
sns.barplot(x= 'horsepower',y='acceleration',data=auto_df,estimator=np.std)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='acceleration'>

# %%
sns.boxplot(x='horsepower',y="weight",hue="acceleration",data=auto_df,palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='weight'>

# %%
dataset = pd.read_csv('auto_mpg_dataset.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,1].values

X
# Out:
# array([[8, 307.0, 130.0, ..., 70, 1, 'chevrolet chevelle malibu'],
#        [8, 350.0, 165.0, ..., 70, 1, 'buick skylark 320'],
#        [8, 318.0, 150.0, ..., 70, 1, 'plymouth satellite'],
#        ...,
#        [4, 135.0, 84.0, ..., 82, 1, 'dodge rampage'],
#        [4, 120.0, 79.0, ..., 82, 1, 'ford ranger'],
#        [4, 119.0, 82.0, ..., 82, 1, 'chevy s-10']], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

X_train
# Out:
# array([[6, 198.0, 95.0, ..., 73, 1, 'plymouth duster'],
#        [4, 89.0, 60.0, ..., 80, 3, 'toyota corolla tercel'],
#        [4, 97.0, 52.0, ..., 82, 2, 'vw pickup'],
#        ...,
#        [4, 68.0, 49.0, ..., 73, 2, 'fiat 128'],
#        [6, 250.0, 100.0, ..., 71, 1, 'pontiac firebird'],
#        [4, 90.0, 71.0, ..., 75, 2, 'volkswagen dasher']], dtype=object)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# %%
y_pred = regressor.predict(X_test)
y_pred

# %%
plt.scatter(X_train, y_train, color = 'green')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(X_test, y_test, color = 'blue')
plt.plot(X_train, regressor.predict(X_train), color = 'red')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
